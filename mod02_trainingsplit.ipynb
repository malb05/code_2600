# %% [markdown]
# # Module 02: Training Splits

# %%
#%pip install islp
# Out:
# Requirement already satisfied: islp in ./.venv/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: numpy>=1.7.1 in ./.venv/lib/python3.12/site-packages (from islp) (2.5.2)
# Requirement already satisfied: scipy>=0.9 in ./.venv/lib/python3.12/site-packages (from islp) (1.16.3)
# Requirement already satisfied: pandas>=1.5 in ./.venv/lib/python3.12/site-packages (from islp) (2.3.3)
# Requirement already satisfied: lxml in ./.venv/lib/python3.12/site-packages (from islp) (6.1.3)
# Requirement already satisfied: scikit-learn>=1.2 in ./.venv/lib/python3.12/site-packages (from islp) (1.9.1)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from islp) (1.6.0)
# Requirement already satisfied: statsmodels>=0.13 in ./.venv/lib/python3.12/site-packages (from islp) (0.15.0)
# Requirement already satisfied: lifelines in ./.venv/lib/python3.12/site-packages (from islp) (0.30.3)
# Requirement already satisfied: pygam in ./.venv/lib/python3.12/site-packages (from islp) (0.12.0)
# Requirement already satisfied: torch in ./.venv/lib/python3.12/site-packages (from islp) (2.14.0)
# Requirement already satisfied: pytorch_lightning in ./.venv/lib/python3.12/site-packages (from islp) (2.6.6)
# Requirement already satisfied: torchmetrics in ./.venv/lib/python3.12/site-packages (from islp) (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas>=1.5->islp) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas>=1.5->islp) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=1.5->islp) (2026.3)
# Requirement already satisfied: narwhals>=2.0.1 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=1.2->islp) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=1.2->islp) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in ./.venv/lib/python3.12/site-packages (from joblib->islp) (3.1.2)
# Requirement already satisfied: patsy>=0.5.6 in ./.venv/lib/python3.12/site-packages (from statsmodels>=0.13->islp) (1.0.3)
# Requirement already satisfied: packaging>=21.3 in ./.venv/lib/python3.12/site-packages (from statsmodels>=0.13->islp) (26.3)
# Requirement already satisfied: formulaic>=1.1.0 in ./.venv/lib/python3.12/site-packages (from statsmodels>=0.13->islp) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0 in ./.venv/lib/python3.12/site-packages (from lifelines->islp) (3.11.1)
# Requirement already satisfied: autograd>=1.5 in ./.venv/lib/python3.12/site-packages (from lifelines->islp) (1.9.1)
# Requirement already satisfied: autograd-gamma>=0.3 in ./.venv/lib/python3.12/site-packages (from lifelines->islp) (0.5.0)
# Requirement already satisfied: progressbar2<5,>=4.2.0 in ./.venv/lib/python3.12/site-packages (from pygam->islp) (4.6.0)
# Requirement already satisfied: tqdm>=4.57.0 in ./.venv/lib/python3.12/site-packages (from pytorch_lightning->islp) (4.70.1)
# Requirement already satisfied: PyYAML>5.4 in ./.venv/lib/python3.12/site-packages (from pytorch_lightning->islp) (6.0.3)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in ./.venv/lib/python3.12/site-packages (from pytorch_lightning->islp) (2026.7.0)
# Requirement already satisfied: typing-extensions>4.5.0 in ./.venv/lib/python3.12/site-packages (from pytorch_lightning->islp) (4.16.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in ./.venv/lib/python3.12/site-packages (from pytorch_lightning->islp) (0.15.3)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch->islp) (3.32.6)
# Requirement already satisfied: setuptools>=77.0.3 in ./.venv/lib/python3.12/site-packages (from torch->islp) (84.0.0)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.12/site-packages (from torch->islp) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./.venv/lib/python3.12/site-packages (from torch->islp) (3.6.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch->islp) (3.1.6)
# Requirement already satisfied: cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3 in ./.venv/lib/python3.12/site-packages (from torch->islp) (13.0.3.0)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in ./.venv/lib/python3.12/site-packages (from torch->islp) (13.4.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.24.0.43 in ./.venv/lib/python3.12/site-packages (from torch->islp) (9.24.0.43)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in ./.venv/lib/python3.12/site-packages (from torch->islp) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.30.7 in ./.venv/lib/python3.12/site-packages (from torch->islp) (2.30.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in ./.venv/lib/python3.12/site-packages (from torch->islp) (3.4.5)
# Requirement already satisfied: triton~=3.8.0 in ./.venv/lib/python3.12/site-packages (from torch->islp) (3.8.0)
# Requirement already satisfied: nvidia-cublas==13.1.1.3.* in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (13.1.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (12.0.0.61)
# Requirement already satisfied: nvidia-nvjitlink<14,>=13.0.88 in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (13.4.52)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (12.6.3.3)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in ./.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3->torch->islp) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in ./.venv/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch->islp) (1.8.1)
# Requirement already satisfied: interface-meta>=1.2.0 in ./.venv/lib/python3.12/site-packages (from formulaic>=1.1.0->statsmodels>=0.13->islp) (2.0.1)
# Requirement already satisfied: wrapt>=1.0 in ./.venv/lib/python3.12/site-packages (from formulaic>=1.1.0->statsmodels>=0.13->islp) (2.4.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./.venv/lib/python3.12/site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning->islp) (3.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines->islp) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines->islp) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines->islp) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines->islp) (1.5.1)
# Requirement already satisfied: pillow>=9 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines->islp) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines->islp) (3.3.2)
# Requirement already satisfied: python-utils>=3.8.1 in ./.venv/lib/python3.12/site-packages (from progressbar2<5,>=4.2.0->pygam->islp) (4.0.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.5->islp) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->islp) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->torch->islp) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->islp) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->islp) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->islp) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->islp) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->islp) (6.8.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->islp) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->islp) (1.24.5)
# Requirement already satisfied: idna>=2.0 in ./.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->islp) (3.19)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Load necessary packages

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from ISLP.models import summarize
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots

# %% [markdown]
# ### Create helper functions for computing predictions and the mean squared error

# %%
def predict(X, model):
    '''
    The built-in "get_prediction" tool in ISLP returns an array, so this is just a wrapper which converts the result to a dataframe.
    '''
    predictions_df = pd.DataFrame(model.get_prediction(X).predicted, columns=['y_hat'], index=X.index)
    return predictions_df['y_hat']

def mse(y, y_hat):
    '''
    Returns the mean squared error, which we will use to evaluate how well a linear regression model fits a dataset.

    The details of this function will be explored further in module 04.
    '''
    # calculate the residual error for each individual record
    resid = y - y_hat
    # square the residual (hence "squared error")
    sq_resid = resid**2
    # calculate the sum of squared errors
    SSR = sum(sq_resid)
    # divide by the number of records to get the mean squared error
    MSE = SSR / y.shape[0]
    return MSE

# %% [markdown]
# ### Randomly generate a dataset using the equation y = x - 2x^2

# %%
# Always specify a seed so that the data can be regenerated
# DON'T change anything in this cell.
seed = 314

# Create a random number generator called rng
rng = np.random.default_rng(seed)

# Use the random number generator to create x- and y-coordinates
x = rng.normal(size=150)
y = x - 2 * x**2 + rng.normal(size=150)

# %% [markdown]
# ### Create a dataframe we can use to build three different models

# %%
# We'll need a collection of independent variables. We'll use x, x^2, x^3, and a constant (which will be used to calculate the intercept)
new_x = pd.DataFrame(np.column_stack((x**0, x, x**2, x**3)), columns=['intercept','x','x_sq','x_cu'])

# print the dataframe
new_x
# Out:
#      intercept         x      x_sq      x_cu
# 0          1.0 -0.623223  0.388407 -0.242064
# 1          1.0 -0.556297  0.309466 -0.172155
# 2          1.0  0.037388  0.001398  0.000052
# 3          1.0  0.995960  0.991937  0.987930
# 4          1.0  0.029919  0.000895  0.000027
# ..         ...       ...       ...       ...
# 145        1.0  0.193035  0.037263  0.007193
# 146        1.0 -0.536687  0.288033 -0.154584
# 147        1.0  0.879224  0.773036  0.679672
# 148        1.0 -0.443387  0.196592 -0.087166
# 149        1.0 -1.246439  1.553609 -1.936479
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Split the data into train and test

# %%
# Note that we need to choose a random seed and the percent of records withheld for testing
x_train, x_test, y_train, y_test = train_test_split(new_x,
                                                    y,
                                                    random_state=314159,
                                                    test_size=0.33,
                                                    shuffle=True)

# %% [markdown]
# ### Graph the training data

# %%
# It's important to do this after the train/test split is created. We shouldn't look at data that's withheld for testing.
fig, ax = plt.subplots()
ax.scatter(x_train['x'],y_train)

# %% [markdown]
# ### First we'll a quadratic model, which should be appropriate since the data was randomly generated based on a quadratic equation

# %%
# Fit a quadratic model
model_quad = sm.OLS(y_train, x_train[['intercept','x','x_sq']])
results_quad = model_quad.fit()
summarize(results_quad)
# Out:
#              coef  std err       t  P>|t|
# intercept  0.0943    0.114   0.830  0.408
# x          0.9255    0.092  10.028  0.000
# x_sq      -1.9932    0.056 -35.579  0.000

# %%
# Get predictions
x_train['pred_sq'] = predict(x_train[['intercept', 'x', 'x_sq']], results_quad)

# %%
# Plot predictions as solid green line, along with the original training data
fig, ax = plt.subplots()
ax.scatter(x_train['x'],y_train)
quadratic = x_train[['x','pred_sq']].sort_values('x')
ax.plot(quadratic['x'],quadratic['pred_sq'], color='green')

# %% [markdown]
# ### Next we'll create an underfit model and observe the performance on training.

# %%
# Fit a linear model
model_lin = sm.OLS(y, x)
results_lin = model_lin.fit()
summarize(results_lin)
# Out:
#       coef  std err      t  P>|t|
# x1  1.5526    0.302  5.134    0.0

# %%
# Get model predictions
x_train['pred_lin'] = predict(x_train[['intercept', 'x', 'x_sq']], results_quad)

# %%
# Plot predictions as solid *orange* line
fig, ax = plt.subplots()
ax.scatter(x_train['x'],y_train)
linear = x_train.sort_values('x')
ax.plot(linear['x'], linear['pred_lin'], color='orange', label='Linear Fit (Underfit)')

# %% [markdown]
# ### And lastly we'll build an overfit model and observe the performance on training.

# %%
# Fit a cubic model
model_cubic = sm.OLS(y_train, x_train[['x']])
results_cubic = model_cubic.fit()
summarize(results_cubic)
# Out:
#      coef  std err      t  P>|t|
# x  1.7462    0.388  4.503    0.0

# %%
# Get predictions
x_train['pred_cu'] = predict(x_train[['intercept', 'x', 'x_sq']], results_quad)

# %%
# Plot predictions as solid *red* line
fig, ax = plt.subplots()
ax.scatter(x_train['x'],y_train)
cubic = x_train.sort_values('x')
ax.plot(cubic['x'], cubic['pred_lin'], color='red', label='Cubic Fit')

# %% [markdown]
# ### After observing the resulting three plots on the training set, how do the models compare? Is one clearly the best? Is one clearly the worst?

# %% [markdown]
# They both are equally the same.

# %% [markdown]
# ### Now we'll calculate the errors (MSE) for each model on the training and test sets.

# %%
# Calculate the MSE on the training set for each model
predictions_lin_train = predict(x_train[['intercept', 'x']], results_lin)
predictions_quad_train = predict(x_train[['intercept', 'x', 'x_sq']], results_quad)
predictions_cubic_train = predict(x_train[['intercept', 'x', 'x_sq', 'x_cu']], results_cubic)

print('mse train linear   :',mse(y_train, predictions_lin_train))
print('mse train quadratic:',mse(y_train, predictions_quad_train))
print('mse train cubic    :',mse(y_train, predictions_cubic_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 2
#       1 # Calculate the MSE on the training set for each model
# ----> 2 predictions_lin_train = predict(x_train[['intercept', 'x']], results_lin)
#       3 predictions_quad_train = predict(x_train[['intercept', 'x', 'x_sq']], results_quad)
#       4 predictions_cubic_train = predict(x_train[['intercept', 'x', 'x_sq', 'x_cu']], results_cubic)
#       5
#
# Cell In[55], line 5, in predict(X, model)
#       1 def predict(X, model):
#       2     '''
#       3     The built-in "get_prediction" tool in ISLP returns an array, so this is just a wrapper which converts the result to a dataframe.
#       4     '''
# ----> 5     predictions_df = pd.DataFrame(model.get_prediction(X).predicted, columns=['y_hat'], index=X.index)
#       6     return predictions_df['y_hat']
#
# File /workspaces/code_2600/.venv/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:3022, in RegressionResults.get_prediction(self, exog, transform, weights, row_labels, **kwargs)
#    3017 @Appender(pred.get_prediction.__doc__)
#    3018 def get_prediction(
#    3019     self, exog=None, transform=True, weights=None, row_labels=None, **kwargs
#    3020 ):
# -> 3022     return pred.get_prediction(
#    3023         self,
#    3024         exog=exog,
#    3025         transform=transform,
#    3026         weights=weights,
#    3027         row_labels=row_labels,
#    3028         **kwargs,
#    3029     )
#
# File /workspaces/code_2600/.venv/lib/python3.12/site-packages/statsmodels/regression/_prediction.py:206, in get_prediction(self, exog, transform, weights, row_labels, pred_kwds)
#     204 if pred_kwds is None:
#     205     pred_kwds = {}
# --> 206 predicted_mean = self.model.predict(self.params, exog, **pred_kwds)
#     208 covb = self.cov_params()
#     209 var_pred_mean = (exog * np.dot(covb, exog.T).T).sum(1)
#
# File /workspaces/code_2600/.venv/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:466, in RegressionModel.predict(self, params, exog)
#     463 if exog is None:
#     464     exog = self.exog
# --> 466 return np.dot(exog, params)
#
# ValueError: shapes (100,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)

# %%
# Calculate the MSE on the test set for each model
predictions_lin_test = predict(x_test[['intercept']])
predictions_quad_test = #fill-in
predictions_cubic_test = #fill-in

print('mse test linear   :',mse(y_test, predictions_lin_test))
print('mse test quadratic:',mse(y_test, predictions_quad_test))
print('mse test cubic    :',mse(y_test, predictions_cubic_test))
# Out:
#   Cell In[31], line 3
#     predictions_quad_test = #fill-in
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Describe the results for each of the three models in terms of their performance on training data and on test data. Which model is most likely underfit? Which is most likely overfit?

# %% [markdown]
# It seems like they are all the same
